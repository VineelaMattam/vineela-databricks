# %%
# %run "/Workspace/Users/user1@xsr890gmail.onmicrosoft.com/LTIMindtree/day4 medallion arch, jobs/includes"

# %%
dbutils.widgets.text("catalog","default")
dbutils.widgets.text("schema","default")
dbutils.widgets.text("file_name","default")

# %%
catalog=dbutils.widgets.get("catalog")
schema=dbutils.widgets.get("schema")
file_name=dbutils.widgets.get("file_name")

# %%
df=spark.read.csv(f"{input_path}{file_name}",header=True,inferSchema=True)

df1=add_ingestion_date(df)

df1.write.mode("overwrite").saveAsTable(f"{catalog}.{schema}.{file_name}")
