-- %% [markdown]
-- # Getting started with notebook

-- %%
%python
print("hello python")

-- %%
%sql
select "hello Sql"

-- %% [markdown]
-- # creating schema

-- %%
use catalog dev;
create schema dev.example;

-- %%
create schema if not exists dev.example;

-- %%
--use catalog dev; 
--use schema example;
create table dev.example.emp (id int primary key, name string)

-- %%
insert into dev.example.emp values (1,'Naval'),(2,'Anil'),(3,'Sangram')

-- %%
select * from dev.example.emp
