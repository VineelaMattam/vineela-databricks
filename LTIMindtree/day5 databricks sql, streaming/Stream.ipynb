# %%
# Structured Streaming

batch:
reader
df=spark.read.csv("path")
writer
df.write.mode("overwrite").saveAsTable("tbalname")

Streaming

df=spark.readStream.csv("path")
df.writeStream.option("checkpointLcoation","path").toTable("tblname")



# Structured Streaming  (open source) limitation
1. user defined the schema 
2. cannot handle schema drift ( change in schema)
3. complex to implment ( python, spark, streaming)



# Autoloader (databricks) built on top of strcutured streaming 
1. no need to define the schema 
2. can handle schema drift

limiation
1- complex to implement (pyspark)



Declartive Spark Pipelines (DSP)= open source.  (formely DLT delta live table ) top of autoloader (top of structured streaming)
1. SQL, pyton/pyspark 


DSP is for Data engineering
- ETL, 
- batch and streaming,
- orchestration,
- cdc
- scd type 1 and scd type 2

# %%
df=spark.read.csv("/Volumes/dev/default/stream/input_files/",header=True,inferSchema=True)

# %%
df.write.mode("append").saveAsTable("dev.default.stream")

# %%
users_schema="Id integer, Name string,Gender string, Salary integer ,Country string, Date string"

# %%
df=spark.readStream.schema(users_schema).csv("/Volumes/dev/default/stream/input_files/",header=True)

df.writeStream.option("checkpointLocation","/Volumes/dev/default/stream/checkpoints").trigger(once=True).toTable("dev.default.stream")

# %%
# %sql
select * from dev.default.stream

# %%
df=spark.readStream.schema(users_schema).csv("/Volumes/dev/default/stream/input_files/",header=True)

df.writeStream.option("checkpointLocation","/Volumes/dev/default/stream/checkpoints").trigger(once=True).toTable("dev.default.stream")
