# %%
# %sql
Spark basic architecture

DF
reading 
write

# %%
data structure of spark
#1. rdd
2. dataframe
#3. dataset

spark latest version df(rdd, dataset)

dataframe= looks like a table

# %%
reader api
df=spark.read.file_format("path")

writer api
df.write.file_format("path")

source(csv) --- target(tables)

# %%
Lazy evalution:
    Transformation 
        1. read
        2. Filter


    Action.
        1.show or display
        2.count
        3.write

# %%
#df_finace=spark.read.csv("/Volumes/dev/default/csv_files/financial_dataset.csv")
df_finace=spark.read.csv("/Volumes/dev/default/csv_files/financial_dataset.csv",header=True,inferSchema=True)

# %%
df_finace.write.saveAsTable("dev.default.finance_pyspark")

# %%
df_finace=spark.read.csv("/Volumes/dev/default/csv_files/financial_dataset.csv",header=True,inferSchema=True)
df_finace.write.mode("overwrite").saveAsTable("dev.default.finance_pyspark")

# %%
# %sql
select * from dev.default.finance_pyspark

# %%
df_deposit=df_finace.filter("TransactionType='Deposit'")

# %%
df_deposit.display()

# %%
df_deposit.count()

# %%
df_finace.display()

# %%
df_finace.show()
