-- %%
ETL / ELT

Way to create a table. 

1. SQL (csv,json, parquet, delta ) (medium sized) (mb to gb)
2. PySpark (csv,json, parquet, delta ) complex (larged sized) (more than gb, tb, pb)
3. UI (limitation: volume, simple dataset)

-- %%
1. Spark SQL (CTAS): create table as select 
i. read_files (table valued function): select * from read_files("path",format=>"format")
ii. Query: select * from file_format.`path`

-- %%
select * from csv.`/Volumes/dev/default/csv_files/financial_dataset.csv`

-- %%
create table dev.default.financial as
select * from read_files("/Volumes/dev/default/csv_files/financial_dataset.csv")

-- %%
--overwrite
create or replace table dev.default.financial as
select * from read_files("/Volumes/dev/default/csv_files/financial_dataset.csv")

-- %%
select * from read_files("/Volumes/dev/default/csv_files/financial_dataset.csv")

-- %%
create table if not exists dev.default.financial as
select * from read_files("/Volumes/dev/default/csv_files/financial_dataset.csv")

-- %%
--append
insert into dev.default.financial select * from read_files("/Volumes/dev/default/csv_files/financial_dataset.csv")

-- %%
select count(*) from dev.default.financial

-- %%
create table catalog.schema.financial as
select * from read_files("path/financial_dataset.csv")

-- %%
select * from dev.default.financial

-- %%
[{'order_id': '1001', 'customer_id': 'C001', 'product': {}'Laptop', 'category': 'Electronics', 'amount': 70000, 'order_date': '2024-06-01', 'city': 'Mumbai'}
{'order_id': '1002', 'customer_id': 'C002', 'product': 'Mobile', 'category': 'Electronics', 'amount': 20000, 'order_date': '2024-06-01', 'city': 'Delhi'}
{'order_id': '1003', 'customer_id': 'C003', 'product': 'Shoes', 'category': 'Fashion', 'amount': 4000, 'order_date': '2024-06-02', 'city': 'Bangalore'}
{'order_id': '1001', 'customer_id': 'C001', 'product': 'Laptop', 'category': 'Electronics', 'amount': 70000, 'order_date': '2024-06-01', 'city': 'Mumbai'}
{'order_id': '1004', 'customer_id': None, 'product': 'Watch', 'category': 'Fashion', 'amount': None, 'order_date': '2024-06-03', 'city': 'Chennai'}
{'order_id': '1005', 'customer_id': 'C005', 'product': 'Tablet', 'category': None, 'amount': 30000, 'order_date': '2024-06-03', 'city': 'Delhi'}
{'order_id': '1006', 'customer_id': 'C006', 'product': 'Mobile', 'category': 'Electronics', 'amount': 25000, 'order_date': '2024-06-04', 'city': None}
{'order_id': '1007', 'customer_id': 'C002', 'product': 'Shoes', 'category': 'Fashion', 'amount': 5000, 'order_date': '2024-06-05', 'city': 'Delhi'}
{'order_id': '1008', 'customer_id': 'C007', 'product': 'Laptop', 'category': 'Electronics', 'amount': 72000, 'order_date': None, 'city': 'Mumbai'}
{'order_id': '1009', 'customer_id': 'C008', 'product': 'Watch', 'category': 'Fashion', 'amount': 8000, 'order_date': '2024-06-06', 'city': 'Chennai'}]

-- %%
select * from json.`/Volumes/dev/default/csv_files/retail_orders.json`

-- %%
select * from read_files("/Volumes/dev/default/csv_files/retail_orders.json",format=>"json")
