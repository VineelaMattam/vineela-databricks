-- %%
delta internals

-- %%
use catalog lakehouse;

-- %%
create schema lakehouse.yourname managed location 'abfss://raw@adlsnaval123.dfs.core.windows.net/lakehouse/yourname'

-- %%
create schema lakehouse.naval managed location 'abfss://raw@adlsnaval123.dfs.core.windows.net/lakehouse/naval'

-- %%
create table lakehouse.naval.demo (id int, name string)

-- %% [markdown]
-- # delta internals
--
-- -- ACID
-- -- Time Travel

-- %%
delta

parquet  (data)
+ 
_delta_logs ( metadata)

1. crc. ==== desc detail table
2. json  ==== desc history
3. checkpoint parquet ( 10-12 transcation)

-- %%
desc extended lakehouse.naval.demo

-- %%
desc detail lakehouse.naval.demo

-- %%
desc history lakehouse.naval.demo

-- %%
insert into lakehouse.naval.demo values(1,'Naval')

-- %%
insert into lakehouse.naval.demo values(2,'krishna'),(3,'Ram');

-- %%
select * from lakehouse.naval.demo

-- %%
Insert into lakehouse.naval.demo values (4,'Dayanada');
Insert into lakehouse.naval.demo values (5,'Eswar');
Insert into lakehouse.naval.demo values (6,'Sangram');

-- %%
delete from lakehouse.naval.demo where id=2

-- %%
select * from lakehouse.naval.demo

-- %%
update lakehouse.naval.demo set name='Krishna' where id=3

-- %% [markdown]
-- ## Optimize
-- small files into large
--
-- ### Zorder
-- indexing by id col
--
--
-- ### Liquid Cluster

-- %%
optimize lakehouse.naval.demo
zorder by id

-- %% [markdown]
-- ## Vacuum
--
-- - no time travel
-- - delete all unused
-- - default rentention as 7 days or 168 hours

-- %%
vacuum lakehouse.naval.demo

-- %%
vacuum lakehouse.naval.demo retain 0 hours

-- %%
ALTER TABLE lakehouse.naval.demo
SET TBLPROPERTIES (
  delta.deletedFileRetentionDuration = '0 hours'
)

-- %%
vacuum lakehouse.naval.demo retain 0 hours --dry run
