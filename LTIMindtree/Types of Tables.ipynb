-- %%
1. Managed Table 

create table tblname (id int)
create table tblname as select * from tble 
spark.read.csv("path").write.saveAsTable("tbnlename")

table in schema/catalog+[parquet(data)+ delta_log(json )] in default location == managed table


DROP managed table. EVERYTHING IS DROP

2. External Table (Unmanaged Table)


create table tblname (id int) location 'adls/ lakehsoue'
create table tblname as select * from tble location 'adls/ lakehsoue'
spark.read.csv("path").write.option("path","adls/").saveAsTable("tbnlename")

table in schema/catalog+ [parquet(data)+ delta_log(json )] in USERS location == EXTERNAL table


Drop unmanaged. [parquet(data)+ delta_log(json )] remanins untouched

-- %%
create table lakehouse.naval.vendor (id int) location 'abfss://raw@adlsnaval123.dfs.core.windows.net/metadata/external/naval/vendor'

-- %%
drop table lakehouse.naval.vendor

-- %%
desc extended lakehouse.naval.demo

-- %%
desc extended lakehouse.naval.vendor

-- %%
select * from delta.`abfss://raw@adlsnaval123.dfs.core.windows.net/metadata/external/naval/vendor`
