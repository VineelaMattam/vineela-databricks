-- %%
%python
delta internals

-- %%
use catalog lakehouse;

-- %%
create schema lakehouse.vineela managed location 'abfss://raw@adlsnaval123.dfs.core.windows.net/lakehouse/vineela'

-- %%
create table lakehouse.vineela.demo (id int, name string)
